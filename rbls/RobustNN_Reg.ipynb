# %%
# !python3 regularization.py --noise-data-train 0 --noise-train 0 --noise-data-test 0 --noise-test 0 --lamb 1 --batch-size 64 --test-batch-size 1000 --epochs 100 --lr 0.001 --weight-decay 0.0 --dry-run --seed 2020 --log-interval 50 --save-model
# Out:
# Use GPU:
# - Name of GPU is: Tesla T4
# - Number of CPU threads 1
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.297034
#  - Test set: Average loss: 2.2923, Accuracy: 1743/10000 (17.43%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.278406
#  - Test set: Average loss: 2.2427, Accuracy: 1298/10000 (12.98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.215386
#  - Test set: Average loss: 2.2150, Accuracy: 2309/10000 (23.09%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.368899
#  - Test set: Average loss: 2.1433, Accuracy: 2090/10000 (20.90%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.144509
#  - Test set: Average loss: 2.0919, Accuracy: 3355/10000 (33.55%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.148206
#  - Test set: Average loss: 2.0340, Accuracy: 3996/10000 (39.96%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.158279
#  - Test set: Average loss: 1.9651, Accuracy: 4634/10000 (46.34%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.045226
#  - Test set: Average loss: 1.8713, Accuracy: 4824/10000 (48.24%)
#
# ...

# %%
# !python3 regularization.py --noise-data-train 4 --noise-train 4 --noise-data-test 4 --noise-test 4 --lamb 5e-5 --batch-size 64 --test-batch-size 1000 --epochs 250 --lr 0.001 --weight-decay 0.0 --dry-run --seed 2020 --log-interval 50 --save-model
# Out:
# Use GPU:
# - Name of GPU is: Tesla T4
# - Number of CPU threads 1
# Train Epoch: 1 [0/60000 (0%)]	Loss: 15.783873
#  - Test set: Average loss: 2.3047, Accuracy: 957/10000 (9.57%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 8.933917
#  - Test set: Average loss: 2.3045, Accuracy: 906/10000 (9.06%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 5.878991
#  - Test set: Average loss: 2.3044, Accuracy: 1014/10000 (10.14%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 3.892341
#  - Test set: Average loss: 2.3040, Accuracy: 1109/10000 (11.09%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 3.070213
#  - Test set: Average loss: 2.3035, Accuracy: 1110/10000 (11.10%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.684434
#  - Test set: Average loss: 2.3033, Accuracy: 1148/10000 (11.48%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.495858
#  - Test set: Average loss: 2.3033, Accuracy: 1235/10000 (12.35%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.394376
#  - Test set: Average loss: 2.3034, Accuracy: 1261/10000 (12.61%)
#
# ...

# %%
# !python3 regularization.py --noise-data-train 4 --noise-train 4 --noise-data-test 4 --noise-test 4 --lamb 0 --batch-size 64 --test-batch-size 1000 --epochs 100 --lr 0.001 --weight-decay 0.0 --dry-run --seed 2020 --log-interval 50 --save-model
# Out:
# Use GPU:
# - Name of GPU is: Tesla T4
# - Number of CPU threads 1
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.297034
#  - Test set: Average loss: 2.6975, Accuracy: 1678/10000 (16.78%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 2.278406
#  - Test set: Average loss: 2.9610, Accuracy: 1028/10000 (10.28%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 2.215386
#  - Test set: Average loss: 3.5304, Accuracy: 1699/10000 (16.99%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 2.368899
#  - Test set: Average loss: 2.6506, Accuracy: 1713/10000 (17.13%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 2.144509
#  - Test set: Average loss: 2.3509, Accuracy: 2293/10000 (22.93%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 2.148206
#  - Test set: Average loss: 2.2041, Accuracy: 3196/10000 (31.96%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 2.158279
#  - Test set: Average loss: 2.0831, Accuracy: 3380/10000 (33.80%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 2.045226
#  - Test set: Average loss: 1.9565, Accuracy: 3630/10000 (36.30%)
#
# ...
